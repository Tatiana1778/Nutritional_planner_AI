# %% [markdown]
# <a href="https://colab.research.google.com/github/Tatiana1778/Nutritional_planner_AI/blob/main/AI_project_nutrition_food_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for data visualization purposes
import seaborn as sns # for statistical data visualization
# %matplotlib inline

# %%
dataset = pd.read_csv("/content/sample_data/food_dataset.csv", delimiter=';')
dataset.head(5)
# Out:
#    Index Food category Type of food Allergens                   Food  \
# 0      1          meat         pork       NaN     Pork Loin (cooked)
# 1      2          meat      chicken       NaN  Chicken Wing (cooked)
# 2      3          meat      chicken       NaN  Chicken Back (cooked)
# 3      4          meat      chicken       NaN    Chicken Leg (fried)
# 4      5          meat       turkey       NaN   Turkey Steak (fried)
#
#    Caloric Value (kcal)  Fat (g)  Saturated Fats (g)  \
# 0                   213       12                   5
# 1                    52        4                   1
# 2                    93        7                   2
# 3                   431       26                   6
# 4                   179       11                   3
#
#    Monounsaturated Fats (g)  Polyunsaturated Fats (g)  ...  Calcium  Copper  \
# 0                         5                         1  ...       15       0
# ...

# %% [markdown]
# # Data Cleanup

# %%
col_names = ['Index','Food_category','Type_of_food','Allergens','Food','Caloric Value (kcal)', 'Fat (g)','Saturated Fats (g)','Monounsaturated Fats (g)', 'Polyunsaturated Fats (g)','Carbohydrates (g)','Sugars (g)','Protein (g)','Dietary Fiber (g)','Cholesterol (mg)','Sodium (mg)','Water (g)','Vitamin A (IU)','Vitamin B1 (mg)','Vitamin B11 (mcg)','Vitamin B12 (mcg)','Vitamin B2 (mg)', 'Vitamin B3 (mg)','Vitamin B5 (mg)','Vitamin B6','Vitamin C','Vitamin D','Vitamin E','Vitamin K','Calcium','Copper','Iron','Magnesium','Manganese','Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density']

dataset.columns = col_names
dataset.columns
# Out:
# Index(['Index', 'Food_category', 'Type_of_food', 'Allergens', 'Food',
#        'Caloric Value (kcal)', 'Fat (g)', 'Saturated Fats (g)',
#        'Monounsaturated Fats (g)', 'Polyunsaturated Fats (g)',
#        'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)', 'Dietary Fiber (g)',
#        'Cholesterol (mg)', 'Sodium (mg)', 'Water (g)', 'Vitamin A (IU)',
#        'Vitamin B1 (mg)', 'Vitamin B11 (mcg)', 'Vitamin B12 (mcg)',
#        'Vitamin B2 (mg)', 'Vitamin B3 (mg)', 'Vitamin B5 (mg)', 'Vitamin B6',
#        'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper',
#        'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium',
#        'Zinc', 'Nutrition Density'],
#       dtype='object')

# %%
# view summary of dataset

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 39 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Index                     300 non-null    int64
#  1   Food_category             300 non-null    object
#  2   Type_of_food              300 non-null    object
#  3   Allergens                 123 non-null    object
#  4   Food                      300 non-null    object
#  5   Caloric Value (kcal)      300 non-null    int64
#  6   Fat (g)                   300 non-null    int64
#  7   Saturated Fats (g)        300 non-null    int64
#  8   Monounsaturated Fats (g)  300 non-null    int64
#  9   Polyunsaturated Fats (g)  300 non-null    int64
#  10  Carbohydrates (g)         300 non-null    int64
#  11  Sugars (g)                300 non-null    int64
#  12  Protein (g)               300 non-null    int64
#  13  Dietary Fiber (g)         300 non-null    int64
# ...

# %%
# view dimensions of dataset
dataset.shape
# Out:
# (300, 39)

# %%
# find categorical variables

categorical = [var for var in dataset.columns if dataset[var].dtype=='O']

print('There are {} categorical variables\n'.format(len(categorical)))

print('The categorical variables are :\n\n', categorical)
# Out:
# There are 4 categorical variables
#
# The categorical variables are :
#
#  ['Food_category', 'Type_of_food', 'Allergens', 'Food']

# %%
# view the categorical variables

dataset[categorical].tail(10)
# Out:
#     Food_category       Type_of_food  Allergens                       Food
# 290        pastry       sweet pastry     Gluten                     waffle
# 291        pastry       sweet pastry     Gluten                   pancakes
# 292        pastry       sweet pastry     Gluten                     muffin
# 293        pastry       sweet pastry     Gluten                      donut
# 294     sweetener  natural sweetener        NaN                      honey
# 295  fruit spread    Fruit preserves        NaN                  fruit jam
# 296        spread         Nut butter  Tree nuts  chocolate hazelnut spread
# 297        spread         Nut butter    Peanuts              peanut butter
# 298  fruit spread    Fruit preserves        NaN           orange marmalade
# 299  fruit spread    Fruit preserves        NaN                apricot jam

# %%
# check labels in region variable
dataset['Type_of_food'] = dataset['Type_of_food'].str.lower()
dataset.Type_of_food.unique()
# Out:
# array(['pork', 'chicken', 'turkey', 'duck', 'quail', 'goose', 'emu',
#        'ostrich', 'beef', 'ham', 'lamb', 'bacon', 'whitefish', 'carp',
#        'wolffish', 'snapper', 'roe', 'whiting', 'salmon', 'american',
#        'shark', 'jellyfish', 'halibut', 'cuttlefish', 'spot', 'salt',
#        'mackerel', 'scup', 'herring', 'sablefish', 'pink', 'northern',
#        'mullet', 'sea', 'sturgeon', 'dolphinfish', 'crayfish', 'perch',
#        'eel', 'caviar', 'bluefish', 'rockfish', 'swordfish', 'sardine',
#        'anchovy', 'sardines', 'tuna', 'eastern', 'shrimp', 'squid',
#        'oyster', 'blue', 'clams', 'lobster', 'haddock', 'pasta', 'rice',
#        'noodles', 'spaghetti', 'bread', 'tortilla', 'potato', 'tomato',
#        'cardoon', 'spinach', 'kale', 'carrot', 'lotus root', 'corn',
#        'radish', 'lettuce', 'avocado', 'peas', 'beet', 'chili pepper',
#        'artichoke', 'onion', 'cabbage', 'parsnip', 'pepper', 'mushrooms',
# ...

# %%
# check missing values in categorical variables

dataset[categorical].isnull().sum()
# Out:
# Food_category      0
# Type_of_food       0
# Allergens        177
# Food               0
# dtype: int64

# %%
# view frequency counts of values in categorical variables

for var in categorical:
    print(dataset[var].value_counts())
# Out:
# Food_category
# fruit           69
# seafood         55
# grain           32
# vegetable       31
# meat            30
# Legume          26
# diary           15
# oil             14
# sauce           11
# protein          4
# pastry           4
# spread           3
# fruit spread     3
# fat              2
# sweetener        1
# Name: count, dtype: int64
# Type_of_food
# fruit        69
# bean         21
# bread        15
# cheese       15
# chicken       7
#              ..
# clams         1
# blue          1
# squid         1
# jellyfish     1
# lobster       1
# Name: count, Length: 106, dtype: int64
# Allergens
# Fish                     55
# Dairy                    14
# Gluten                   13
# Gluten, Soy               9
# Soy                       9
# Gluten, Soy, Dairy        5
# Tree nuts                 3
# Eggs                      3
# Sesame                    2
# Egg, Gluten               1
# Mustard                   1
# Cheese                    1
# ...

# %%
# view frequency distribution of categorical variables

for var in categorical:
    # Use float(len(dataset)) instead of np.float(len(dataset))
    print(dataset[var].value_counts() / float(len(dataset)))
# Out:
# Food_category
# fruit           0.230000
# seafood         0.183333
# grain           0.106667
# vegetable       0.103333
# meat            0.100000
# Legume          0.086667
# diary           0.050000
# oil             0.046667
# sauce           0.036667
# protein         0.013333
# pastry          0.013333
# spread          0.010000
# fruit spread    0.010000
# fat             0.006667
# sweetener       0.003333
# Name: count, dtype: float64
# Type_of_food
# fruit        0.230000
# bean         0.070000
# bread        0.050000
# cheese       0.050000
# chicken      0.023333
#                ...
# clams        0.003333
# blue         0.003333
# squid        0.003333
# jellyfish    0.003333
# lobster      0.003333
# Name: count, Length: 106, dtype: float64
# Allergens
# Fish                     0.183333
# Dairy                    0.046667
# Gluten                   0.043333
# Gluten, Soy              0.030000
# Soy                      0.030000
# Gluten, Soy, Dairy       0.016667
# ...

# %%
# check frequency distribution of values in region variable

dataset.Type_of_food.value_counts()
# Out:
# Type_of_food
# fruit        69
# bean         21
# bread        15
# cheese       15
# chicken       7
#              ..
# clams         1
# blue          1
# squid         1
# jellyfish     1
# lobster       1
# Name: count, Length: 106, dtype: int64

# %%
dataset[['Type_of_food','Caloric Value (kcal)']]
# Out:
#         Type_of_food  Caloric Value (kcal)
# 0               pork                   213
# 1            chicken                    52
# 2            chicken                    93
# 3            chicken                   431
# 4             turkey                   179
# ..               ...                   ...
# 295  fruit preserves                    56
# 296       nut butter                   100
# 297       nut butter                    88
# 298  fruit preserves                    49
# 299  fruit preserves                    48
#
# [300 rows x 2 columns]

# %%
# find numerical variables

numerical = [var for var in dataset.columns if dataset[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :', numerical)
# Out:
# There are 35 numerical variables
#
# The numerical variables are : ['Index', 'Caloric Value (kcal)', 'Fat (g)', 'Saturated Fats (g)', 'Monounsaturated Fats (g)', 'Polyunsaturated Fats (g)', 'Carbohydrates (g)', 'Sugars (g)', 'Protein (g)', 'Dietary Fiber (g)', 'Cholesterol (mg)', 'Sodium (mg)', 'Water (g)', 'Vitamin A (IU)', 'Vitamin B1 (mg)', 'Vitamin B11 (mcg)', 'Vitamin B12 (mcg)', 'Vitamin B2 (mg)', 'Vitamin B3 (mg)', 'Vitamin B5 (mg)', 'Vitamin B6', 'Vitamin C', 'Vitamin D', 'Vitamin E', 'Vitamin K', 'Calcium', 'Copper', 'Iron', 'Magnesium', 'Manganese', 'Phosphorus', 'Potassium', 'Selenium', 'Zinc', 'Nutrition Density']

# %%
# view the numerical variables

dataset[numerical].head()
# Out:
#    Index  Caloric Value (kcal)  Fat (g)  Saturated Fats (g)  \
# 0      1                   213       12                   5
# 1      2                    52        4                   1
# 2      3                    93        7                   2
# 3      4                   431       26                   6
# 4      5                   179       11                   3
#
#    Monounsaturated Fats (g)  Polyunsaturated Fats (g)  Carbohydrates (g)  \
# 0                         5                         1                  0
# 1                         1                         1                  0
# 2                         3                         1                  0
# 3                        10                         6                 14
# 4                         4                         3                 11
#
#    Sugars (g)  Protein (g)  Dietary Fiber (g)  ...  Calcium  Copper  Iron  \
# 0           0           24                  0  ...       15       0     1
# ...

# %%
# check missing values in numerical variables

dataset[numerical].isnull().sum()
# Out:
# Index                       0
# Caloric Value (kcal)        0
# Fat (g)                     0
# Saturated Fats (g)          0
# Monounsaturated Fats (g)    0
# Polyunsaturated Fats (g)    0
# Carbohydrates (g)           0
# Sugars (g)                  0
# Protein (g)                 0
# Dietary Fiber (g)           0
# Cholesterol (mg)            0
# Sodium (mg)                 0
# Water (g)                   0
# Vitamin A (IU)              0
# Vitamin B1 (mg)             0
# Vitamin B11 (mcg)           0
# Vitamin B12 (mcg)           0
# Vitamin B2 (mg)             0
# Vitamin B3 (mg)             0
# Vitamin B5 (mg)             0
# Vitamin B6                  0
# Vitamin C                   0
# Vitamin D                   0
# Vitamin E                   0
# Vitamin K                   0
# Calcium                     0
# Copper                      0
# Iron                        0
# Magnesium                   0
# Manganese                   0
# Phosphorus                  0
# ...

# %% [markdown]
# #Split Data into Training & Testing datasets

# %%
X = dataset.drop(['Caloric Value (kcal)'], axis=1) #x has dropped calories

y = dataset['Caloric Value (kcal)'] #y has just calories and every other are droppped

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
dataset.shape
# Out:
# (300, 39)

# %%
y_train
# Out:
# 134      8
# 145    114
# 63     182
# 293    192
# 285     97
#       ...
# 251     64
# 192    241
# 117    161
# 47     755
# 172     80
# Name: Caloric Value (kcal), Length: 240, dtype: int64

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((240, 38), (60, 38))

# %% [markdown]
# #Further Data Processing

# %%
# check data types in X_train

X_train.dtypes
# Out:
# Index                        int64
# Food_category               object
# Type_of_food                object
# Allergens                   object
# Food                        object
# Fat (g)                      int64
# Saturated Fats (g)           int64
# Monounsaturated Fats (g)     int64
# Polyunsaturated Fats (g)     int64
# Carbohydrates (g)            int64
# Sugars (g)                   int64
# Protein (g)                  int64
# Dietary Fiber (g)            int64
# Cholesterol (mg)             int64
# Sodium (mg)                  int64
# Water (g)                    int64
# Vitamin A (IU)               int64
# Vitamin B1 (mg)              int64
# Vitamin B11 (mcg)            int64
# Vitamin B12 (mcg)            int64
# Vitamin B2 (mg)              int64
# Vitamin B3 (mg)              int64
# Vitamin B5 (mg)              int64
# Vitamin B6                   int64
# Vitamin C                    int64
# Vitamin D                    int64
# Vitamin E                    int64
# ...

# %%
# display categorical variables

categorical = [col for col in X_train.columns if X_train[col].dtypes == 'O']

categorical
# Out:
# ['Food_category', 'Type_of_food', 'Allergens', 'Food']

# %%
# display numerical variables

numerical = [col for col in X_train.columns if X_train[col].dtypes != 'O']

numerical
# Out:
# ['Index',
#  'Fat (g)',
#  'Saturated Fats (g)',
#  'Monounsaturated Fats (g)',
#  'Polyunsaturated Fats (g)',
#  'Carbohydrates (g)',
#  'Sugars (g)',
#  'Protein (g)',
#  'Dietary Fiber (g)',
#  'Cholesterol (mg)',
#  'Sodium (mg)',
#  'Water (g)',
#  'Vitamin A (IU)',
#  'Vitamin B1 (mg)',
#  'Vitamin B11 (mcg)',
#  'Vitamin B12 (mcg)',
#  'Vitamin B2 (mg)',
#  'Vitamin B3 (mg)',
#  'Vitamin B5 (mg)',
#  'Vitamin B6',
#  'Vitamin C',
#  'Vitamin D',
#  'Vitamin E',
#  'Vitamin K',
#  'Calcium',
#  'Copper',
#  'Iron',
#  'Magnesium',
#  'Manganese',
#  'Phosphorus',
#  'Potassium',
#  'Selenium',
#  'Zinc',
#  'Nutrition Density']

# %%
# print percentage of missing values in the categorical variables in training set

X_train[categorical].isnull().mean()
# Out:
# Food_category    0.000000
# Type_of_food     0.000000
# Allergens        0.570833
# Food             0.000000
# dtype: float64

# %%
# print categorical variables with missing data

for col in categorical:
    if X_train[col].isnull().mean()>0:
        print(col, (X_train[col].isnull().mean()),2)
# Out:
# Allergens 0.5708333333333333 2

# %%
# impute missing categorical variables with most frequent value

for df2 in [X_train, X_test]:
    df2['Allergens'].fillna(X_train['Allergens'].mode()[0], inplace=True)
# Out:
# <ipython-input-29-e6ccb3f716e5>:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Allergens'].fillna(X_train['Allergens'].mode()[0], inplace=True)

# %%
# check missing values in categorical variables in X_train

X_train[categorical].isnull().sum()
# Out:
# Food_category    0
# Type_of_food     0
# Allergens        0
# Food             0
# dtype: int64

# %%
# check missing values in categorical variables in X_test

X_test[categorical].isnull().sum()
# Out:
# Food_category    0
# Type_of_food     0
# Allergens        0
# Food             0
# dtype: int64

# %%
# check missing values in X_train

X_train.isnull().sum()
# Out:
# Index                       0
# Food_category               0
# Type_of_food                0
# Allergens                   0
# Food                        0
# Fat (g)                     0
# Saturated Fats (g)          0
# Monounsaturated Fats (g)    0
# Polyunsaturated Fats (g)    0
# Carbohydrates (g)           0
# Sugars (g)                  0
# Protein (g)                 0
# Dietary Fiber (g)           0
# Cholesterol (mg)            0
# Sodium (mg)                 0
# Water (g)                   0
# Vitamin A (IU)              0
# Vitamin B1 (mg)             0
# Vitamin B11 (mcg)           0
# Vitamin B12 (mcg)           0
# Vitamin B2 (mg)             0
# Vitamin B3 (mg)             0
# Vitamin B5 (mg)             0
# Vitamin B6                  0
# Vitamin C                   0
# Vitamin D                   0
# Vitamin E                   0
# Vitamin K                   0
# Calcium                     0
# Copper                      0
# Iron                        0
# ...

# %%
# check missing values in X_test

X_test.isnull().sum()
# Out:
# Index                       0
# Food_category               0
# Type_of_food                0
# Allergens                   0
# Food                        0
# Fat (g)                     0
# Saturated Fats (g)          0
# Monounsaturated Fats (g)    0
# Polyunsaturated Fats (g)    0
# Carbohydrates (g)           0
# Sugars (g)                  0
# Protein (g)                 0
# Dietary Fiber (g)           0
# Cholesterol (mg)            0
# Sodium (mg)                 0
# Water (g)                   0
# Vitamin A (IU)              0
# Vitamin B1 (mg)             0
# Vitamin B11 (mcg)           0
# Vitamin B12 (mcg)           0
# Vitamin B2 (mg)             0
# Vitamin B3 (mg)             0
# Vitamin B5 (mg)             0
# Vitamin B6                  0
# Vitamin C                   0
# Vitamin D                   0
# Vitamin E                   0
# Vitamin K                   0
# Calcium                     0
# Copper                      0
# Iron                        0
# ...

# %%
# print categorical variables

categorical
# Out:
# ['Food_category', 'Type_of_food', 'Allergens', 'Food']

# %%
X_train[categorical].head()
# Out:
#     Food_category  Type_of_food Allergens                 Food
# 134     vegetable       lettuce      Fish      romaine lettuce
# 145     vegetable       parsnip      Fish      parsnips cooked
# 63        seafood     swordfish      Fish     swordfish cooked
# 293        pastry  sweet pastry    Gluten                donut
# 285         fruit         fruit      Fish  blackberries frozen

# %% [markdown]
# #Encode Categorical Data into Numbers

# %%
# import category encoders
# !pip install category_encoders
from sklearn import preprocessing
import category_encoders as ce
encoder = ce.OneHotEncoder(cols=['Type_of_food', 'Food_category', 'Allergens','Food'])
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.0/82.0 kB 3.4 MB/s eta 0:00:00
# ...

# %%
# encode remaining variables with one-hot encoding

X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:411: FutureWarning: The `_get_tags` method is deprecated in 1.6 and will be removed in 1.7. Please implement the `__sklearn_tags__` method.
#   warnings.warn(

# %%
X_train.head()
# Out:
#      Index  Food_category_1  Food_category_2  Food_category_3  \
# 134    135                1                0                0
# 145    146                1                0                0
# 63      64                0                1                0
# 293    294                0                0                1
# 285    286                0                0                0
#
#      Food_category_4  Food_category_5  Food_category_6  Food_category_7  \
# 134                0                0                0                0
# 145                0                0                0                0
# 63                 0                0                0                0
# 293                0                0                0                0
# 285                1                0                0                0
#
#      Food_category_8  Food_category_9  ...  Calcium  Copper  Iron  Magnesium  \
# 134                0                0  ...       16       0     1          7
# ...

# %%
X_train.shape
# Out:
# (240, 396)

# %%
X_test.head()
# Out:
#      Index  Food_category_1  Food_category_2  Food_category_3  \
# 208    209                0                0                0
# 188    189                0                0                0
# 12      13                0                0                0
# 221    222                0                0                0
# 239    240                0                0                0
#
#      Food_category_4  Food_category_5  Food_category_6  Food_category_7  \
# 208                0                0                0                0
# 188                0                0                0                0
# 12                 0                0                1                0
# 221                1                0                0                0
# 239                1                0                0                0
#
#      Food_category_8  Food_category_9  ...  Calcium  Copper  Iron  Magnesium  \
# 208                0                0  ...        0       0     0          0
# ...

# %%
X_test.shape
# Out:
# (60, 396)

# %%
cols = X_train.columns

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train = pd.DataFrame(X_train, columns=[cols])

# %%
X_test = pd.DataFrame(X_test, columns=[cols])

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# #Train on Training Data

# %%
# train a Gaussian Naive Bayes classifier on the training set
from sklearn.naive_bayes import GaussianNB
#from sklearn.neighbors import KNeighborsClassifier

# instantiate the model
gnb = GaussianNB()
#gnb = KNeighborsClassifier(3)


# fit the model
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# #Predict Y based on X variables

# %%
y_pred = gnb.predict(X_test)

y_pred
# Out:
# array([ 39, 227, 294,  59, 227, 118, 316, 117, 290,  83,  86, 165, 227,
#         35, 294,  52, 117, 118,  17, 103, 190,  46,  18,   7,  33, 103,
#        227,   5, 117,  49,  86, 294, 118,  18, 120,  86,   6, 227,  49,
#        165,  17,  93,  52,  52, 227,  25, 117,  86, 165,  33,  52, 120,
#        316,  93, 227,  86,  98, 294,  86,  86])

# %% [markdown]
# #Determine Accuracy

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score: {0:0.4f}'. format(accuracy_score(y_test, y_pred)))
# Out:
# Model accuracy score: 0.0500

# %%
y_pred_train = gnb.predict(X_train)

y_pred_train
# Out:
# array([  8, 114, 182, 192,  97,  45, 399,  83, 190, 290, 123, 316,  37,
#        294,  58, 157, 363, 103, 190,  18,  52,  30,  18, 117,  35,   8,
#        120, 253,  20,  37, 101, 231,   7, 245,  72,  29,  93, 184, 352,
#        242, 227,  59,   7, 316, 331,  17,  46,  94, 202, 120, 119,  51,
#        218,  33,   2,  79, 103,  33, 128, 320, 106,  19, 143,  25,  41,
#        128, 100, 269,  30, 179,  95, 100, 186, 165, 134, 227, 118,   6,
#        353,  84, 135, 151, 120, 431,  13,  26, 294, 265, 344,  86, 120,
#        145,  17,  63,  71, 134, 824,  93,   4,  83, 287,  37, 165, 228,
#         67,  45, 118,  86, 350, 169,   5,   5, 294, 162, 189,   3,   6,
#        120,  92, 415, 467,  22,  64,  40,  59,  75,  62, 105, 120, 301,
#        120, 113, 733, 310,  85, 213, 146,  93,  98, 100,  53, 112, 530,
#        265, 349, 176,  88,  64,  39, 296, 102,  16,  35,  52, 187,  79,
#        120,  99, 179,  49, 239, 472, 102, 202, 147,  98,  74,  18, 117,
# ...

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 1.0000

# %% [markdown]
# #Run Predictions on Test Data

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(gnb.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(gnb.score(X_test, y_test)))
# Out:
# Training set score: 1.0000
# Test set score: 0.0500

# %% [markdown]
# #Accuracy

# %%
# check class distribution in test set

y_test.value_counts()
# Out:
# Caloric Value (kcal)
# 42      3
# 218     3
# 294     2
# 140     2
# 173     1
# 119     1
# 418     1
# 94      1
# 255     1
# 48      1
# 193     1
# 8       1
# 169     1
# 61      1
# 58      1
# 45      1
# 520     1
# 23      1
# 310     1
# 216     1
# 68      1
# 7       1
# 124     1
# 159     1
# 73      1
# 206     1
# 90      1
# 1028    1
# 56      1
# 375     1
# 95      1
# 135     1
# 66      1
# 86      1
# 432     1
# 237     1
# 1927    1
# 82      1
# 137     1
# 299     1
# 30      1
# 40      1
# 160     1
# 19      1
# 253     1
# 47      1
# 32      1
# 16      1
# 51      1
# 52      1
# 241     1
# 5       1
# 17      1
# 70      1
# Name: count, dtype: int64

# %%
# check null accuracy score

null_accuracy = (7407/(7407+2362))

print('Null accuracy score: {0:0.4f}'. format(null_accuracy))
# Out:
# Null accuracy score: 0.7582
